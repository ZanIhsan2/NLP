# %% [markdown]
# ### Crawl Twet

# %%
#@title Twitter Auth Token
# auth token ambil dari cookies parameter auth token
twitter_auth_token = 'fb53294ce80c28916acaa83dae2b909d6c337933' # change this auth token

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v

# %%
# !apt-get update
# !apt-get install -y \
  libatk1.0-0 \
  libatk-bridge2.0-0 \
  libcups2 \
  libxkbcommon0 \
  libxcomposite1 \
  libxdamage1 \
  libxrandr2 \
  libgbm1 \
  libasound2 \
  libpangocairo-1.0-0 \
  libpango-1.0-0 \
  libcairo2 \
  libgtk-3-0

# %%
# !npx playwright install chromium

# %%
# Crawl Data

filename = 'filedataset.csv'
# search_keyword = 'from:detikcom lang:id since:2025-10-01 until:2026-02-30'
search_keyword = 'from:detikcom lang:id '
limit = 100

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}

# %% [markdown]
# ### Load Data Crawl Twet

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/filedataset.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

df.to_csv('filedataset.csv', index=False)

# Display the DataFrame
df.head()
