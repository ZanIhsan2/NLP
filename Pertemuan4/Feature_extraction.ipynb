# %% [markdown]
# **Bag of Words**

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

docs = [
    "kopi ini enak",
    "kopi ini tidak enak",
    "kopi mahal"
]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(docs)

dtm_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
dtm_df.index = ["R1", "R2", "R3"]
dtm_df
# Out:
#     enak  ini  kopi  mahal  tidak
# R1     1    1     1      0      0
# R2     1    1     1      0      1
# R3     0    0     1      1      0

# %%
term_freq = dtm_df.sum(axis=0)
term_freq.sort_values().plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# **TF-IDF**

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

docs = [
    "kopi ini enak",
    "kopi ini tidak enak",
    "kopi mahal"
]

tfidf = TfidfVectorizer(norm=None, use_idf=True, smooth_idf=False)  # non-normalized biar lebih jelas
X = tfidf.fit_transform(docs)

# Vocabulary
vocab = tfidf.get_feature_names_out()

# IDF
idf = tfidf.idf_

# TF-IDF Matrix
tfidf_matrix = X.toarray()

print("Vocabulary:", vocab)

print("\nIDF:")
for word, val in zip(vocab, idf):
    print(f"{word}: {round(val,3)}")

print("\nTF-IDF Matrix:")
print(tfidf_matrix)
# Out:
# Vocabulary: ['enak' 'ini' 'kopi' 'mahal' 'tidak']
#
# IDF:
# enak: 1.405
# ini: 1.405
# kopi: 1.0
# mahal: 2.099
# tidak: 2.099
#
# TF-IDF Matrix:
# [[1.40546511 1.40546511 1.         0.         0.        ]
#  [1.40546511 1.40546511 1.         0.         2.09861229]
#  [0.         0.         1.         2.09861229 0.        ]]
