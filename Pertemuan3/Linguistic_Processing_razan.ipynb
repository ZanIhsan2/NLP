# %% [markdown]
# ---
# # Pertemuan Ke 3
# ## Natural Language Processing
# ## Linguistic Processing #
#
# Oleh: Muhammad Yazid Supriadi S.Kom, M.Kom
#
# ---

# %% [markdown]
# # Install library

# %%
#install library here
# !pip install requests
# !pip install beautifulsoup4
# !pip install nltk
# !pip install Sastrawi
# !pip install stanza
# !pip install matplotlib
# !pip install wordcloud
# !pip install networkx
# !pip install pyvis
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting stanza
#   Downloading stanza-1.11.1-py3-none-any.whl.metadata (14 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from stanza) (4.9.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (5.29.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from stanza) (2.32.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from stanza) (3.6.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (2.10.0+cpu)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stanza) (4.67.3)
# Collecting udtools>=0.2.4 (from stanza)
#   Downloading udtools-0.2.7-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (2025.3.0)
# Collecting udapi>=0.5.0 (from udtools>=0.2.4->stanza)
#   Downloading udapi-0.5.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: regex>=2020.09.27 in /usr/local/lib/python3.12/dist-packages (from udtools>=0.2.4->stanza) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->stanza) (1.3.0)
# Collecting colorama (from udapi>=0.5.0->udtools>=0.2.4->stanza)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from udapi>=0.5.0->udtools>=0.2.4->stanza) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->stanza) (3.0.3)
# Downloading stanza-1.11.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.3 MB/s eta 0:00:00
# Downloading udtools-0.2.7-py3-none-any.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.7/773.7 kB 34.7 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 21.7 MB/s eta 0:00:00
# Downloading udapi-0.5.1-py3-none-any.whl (337 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.2/337.2 kB 20.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: emoji, colorama, udapi, udtools, stanza
# Successfully installed colorama-0.4.6 emoji-2.15.0 stanza-1.11.1 udapi-0.5.1 udtools-0.2.7
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.12/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.6.1)
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.12/dist-packages (from pyvis) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from pyvis) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.12/dist-packages (from pyvis) (3.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9.6->pyvis) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.6.0)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 13.4 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.0 MB/s eta 0:00:00
# Installing collected packages: jedi, pyvis
# Successfully installed jedi-0.19.2 pyvis-0.3.2

# %% [markdown]
# # Import Library

# %%
#import library here
import requests
import re
import nltk
import stanza
import networkx as nx
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from collections import Counter

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from wordcloud import WordCloud

# %%
# download punkt, stopword and stanza
nltk.download("punkt")
nltk.download("stopwords")
stanza.download("id")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/resources.json
# INFO:stanza:Downloading default packages for language: id (Indonesian) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-id/resolve/v1.11.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/id/default.zip
# INFO:stanza:Finished downloading models and saved to /root/.cache/stanza/1.11.0/resources
# [['zip', 'default.zip']]

# %% [markdown]
# # Crawling Artikel Berita

# %%
url = "https://nasional.kompas.com/read/2026/03/04/15384751/bupati-pekalongan-fadia-arafiq-dan-anaknya-intervensi-kadis-untuk-pakai-jasa"

response = requests.get(url)

soup = BeautifulSoup(response.text,"html.parser")

paragraphs = soup.find_all("p")

article = ""

for p in paragraphs:
    article += p.text + " "

print(article[:4000])
# Out:
# Bupati Pekalongan Fadia Arafiq dan Anaknya Intervensi Kadis untuk Pakai Jasa Perusahaan Mereka Tim Redaksi JAKARTA, KOMPAS.com - Komisi Pemberantasan Korupsi (KPK) mengatakan, Bupati Pekalongan Fadia Arafiq melalui anaknya yang menjabat sebagai Anggota DPRD, Muhammad Sabiq Ashraff, dan orang kepercayaannya diduga melakukan intervensi kepada sejumlah Perangkat Daerah Pemkab Pekalongan agar memakai perusahaan mereka yakni PT RNB (Raja Nusantara Berjaya) untuk pengadaan barang dan jasa outsourcing. Hal tersebut disampaikan Deputi Penindakan dan Eksekusi KPK Asep Guntur Rahayu saat mengumumkan status tersangka terhadap Fadia Arafiq terkait kasus pengadaan barang dan jasa outsourcing di lingkungan Pemkab Pekalongan. “Pada periode tersebut (2024), FAR (Fadia Arafiq) melalui anaknya, (Muhammad Sabiq Ashraff) dan orang kepercayaannya diduga melakukan intervensi kepada para Kepala Dinas agar memenangkan PT RNB untuk pengadaan jasa outsourcing di sejumlah dinas, kecamatan, hingga Rumah Sakit Umum Daerah (RSUD) di Kabupaten Pekalongan,” kata Asep dalam konferensi pers di Gedung Merah Putih, Jakarta, Rabu (4/3/2026). Baca juga: Fadia Arafiq Tempatkan Orang Kepercayaan di Perusahaan yang Menang Proyek di Pekalongan Asep mengatakan, meskipun ada perusahaan lain yang mengajukan penawaran pengadaan dengan nilai yang rendah, para perangkat daerah harus memenangkan “perusahaan ibu” PT RNB. “Sehingga hal itu juga berpotensi dapat menimbulkan kerugian keuangan negara,” ujarnya. Asep mengatakan, setiap perangkat daerah yang akan melakukan pengadaan diminta menyerahkan Harga Perkiraan Sendiri (HPS) kepada PT RNB di awal, agar PT RNB bisa menyesuaikan nilai penawaran yang mendekati angka HPS. “Hal itu melanggar prosedur dalam proses pengadaan barang dan jasa,” tuturnya. Asep juga mengungkapkan, sepanjang tahun 2025, PT RNB mendominasi proyek pengadaan barang dan jasa (PBJ) di Pemkab Pekalongan dengan mengerjakan pengadaan jasa outsourcing di 17 Perangkat Daerah, 3 RSUD, dan 1 Kecamatan. Baca juga: Dominasi Proyek Outsourcing, Keluarga Bupati Pekalongan Fadia Arafiq Kantongi Untung Rp 19 Miliar Selain itu, sepanjang tahun 2023 - 2026, terdapat transaksi masuk ke PT RNB senilai Rp46 miliar yang bersumber dari kontrak antara PT RNB dan Perangkat Daerah di Pemkab Pekalongan. Kemudian dari uang tersebut, yang digunakan untuk pembayaran gaji pegawai outsourcing hanya sebesar Rp22 miliar. Sisa diantaranya, dinikmati dan dibagikan kepada keluarga Bupati dengan total mencapai Rp19 miliar (sekitar 40 persen) dari total transaksi. Rinciannya, Bupati Pekalongan Fadia Arafiq sebesar Rp 5,5 miliar; Muhammad Sabiq Ashraff (suami bupati) Rp 1,1 miliar; Rul Bayatun selaku Direktur PT RNB Rp 2,3 miliar; Muhammad Sabiq Ashraff (anak bupati) Rp 4,6 miliar; Mehnaz (anak bupati) Rp 2,5 miliar; serta dilakukan penarikan tunai sebesar Rp3 miliar. Asep mengatakan, pengelolaan dan distribusi uang tersebut diatur oleh Fadia Arafiq. Ia mengatakan, pengaturan dilakukan melalui komunikasi WA Grup bernama “Belanja RSUD” bersama para stafnya. “Setiap pengambilan uang untuk Bupati, staf selalu melaporkan, mendokumentasikan, dan mengirimkannya melalui WA Grup tersebut. Penyidik juga masih akan terus menelusuri apakah perusahaan ini juga digunakan untuk melakukan modus dalam penerimaan lainnya,” ucap dia. Atas perbuatannya, Fadia disangkakan telah melakukan tindak pidana korupsi sebagaimana diatur dalam Pasal 12 huruf i dan Pasal 12 B Undang-Undang RI Nomor 31 Tahun 1999 tentang Pemberantasan Tindak Pidana Korupsi sebagaimana telah diubah dengan Undang-Undang RI Nomor 20 Tahun 2001 tentang Perubahan Atas Undang-Undang RI Nomor 31 Tahun 1999 tentang Pemberantasan Tindak Pidana Korupsi Jo. Pasal 127 ayat (1) Undang-Undang Nomor 1 Tahun 2023 tentang Kitab Undang-Undang Hukum Pidana (KUHP).               Copyright 2008 - 2026 PT. Kompas Cyber Media (Kompas Gramedia Digital Group). All Rights Reserved.

# %% [markdown]
# # Text Cleaning

# %%
import re

def remove_metadata(text):

  patterns = [
      r"tim prediksi.?kompas",
      r"kompas\.?com",
      r"kompas\.?id",
      r"baca juga.*"
      r"baca.*"
      r"tim redaksi jakarta"
  ]

  for p in patterns:
    text = re.sub(p, "", text)

  return text

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def normalize_suffix(word):
  suffixes = [
      "nya",
      "lah",
      "pun",
      "kah"
  ]

  for suffix in suffixes:
    if word.endswith(suffix):
      word = word[:-len(suffix)]

  return word

# %%
stopword_list = stopwords.words("indonesian")
print(stopword_list)
# Out:
# ['ada', 'adalah', 'adanya', 'adapun', 'agak', 'agaknya', 'agar', 'akan', 'akankah', 'akhir', 'akhiri', 'akhirnya', 'aku', 'akulah', 'amat', 'amatlah', 'anda', 'andalah', 'antar', 'antara', 'antaranya', 'apa', 'apaan', 'apabila', 'apakah', 'apalagi', 'apatah', 'artinya', 'asal', 'asalkan', 'atas', 'atau', 'ataukah', 'ataupun', 'awal', 'awalnya', 'bagai', 'bagaikan', 'bagaimana', 'bagaimanakah', 'bagaimanapun', 'bagi', 'bagian', 'bahkan', 'bahwa', 'bahwasanya', 'baik', 'bakal', 'bakalan', 'balik', 'banyak', 'bapak', 'baru', 'bawah', 'beberapa', 'begini', 'beginian', 'beginikah', 'beginilah', 'begitu', 'begitukah', 'begitulah', 'begitupun', 'bekerja', 'belakang', 'belakangan', 'belum', 'belumlah', 'benar', 'benarkah', 'benarlah', 'berada', 'berakhir', 'berakhirlah', 'berakhirnya', 'berapa', 'berapakah', 'berapalah', 'berapapun', 'berarti', 'berawal', 'berbagai', 'berdatangan', 'beri', 'berikan', 'berikut', 'berikutnya', 'berjumlah', 'berkali-kali', 'berkata', 'berkehendak', 'berkeinginan', 'berkenaan', 'berlainan', 'berlalu', 'berlangsung', 'berlebihan', 'bermacam', 'bermacam-macam', 'bermaksud', 'bermula', 'bersama', 'bersama-sama', 'bersiap', 'bersiap-siap', 'bertanya', 'bertanya-tanya', 'berturut', 'berturut-turut', 'bertutur', 'berujar', 'berupa', 'besar', 'betul', 'betulkah', 'biasa', 'biasanya', 'bila', 'bilakah', 'bisa', 'bisakah', 'boleh', 'bolehkah', 'bolehlah', 'buat', 'bukan', 'bukankah', 'bukanlah', 'bukannya', 'bulan', 'bung', 'cara', 'caranya', 'cukup', 'cukupkah', 'cukuplah', 'cuma', 'dahulu', 'dalam', 'dan', 'dapat', 'dari', 'daripada', 'datang', 'dekat', 'demi', 'demikian', 'demikianlah', 'dengan', 'depan', 'di', 'dia', 'diakhiri', 'diakhirinya', 'dialah', 'diantara', 'diantaranya', 'diberi', 'diberikan', 'diberikannya', 'dibuat', 'dibuatnya', 'didapat', 'didatangkan', 'digunakan', 'diibaratkan', 'diibaratkannya', 'diingat', 'diingatkan', 'diinginkan', 'dijawab', 'dijelaskan', 'dijelaskannya', 'dikarenakan', 'dikatakan', 'dikatakannya', 'dikerjakan', 'diketahui', 'diketahuinya', 'dikira', 'dilakukan', 'dilalui', 'dilihat', 'dimaksud', 'dimaksudkan', 'dimaksudkannya', 'dimaksudnya', 'diminta', 'dimintai', 'dimisalkan', 'dimulai', 'dimulailah', 'dimulainya', 'dimungkinkan', 'dini', 'dipastikan', 'diperbuat', 'diperbuatnya', 'dipergunakan', 'diperkirakan', 'diperlihatkan', 'diperlukan', 'diperlukannya', 'dipersoalkan', 'dipertanyakan', 'dipunyai', 'diri', 'dirinya', 'disampaikan', 'disebut', 'disebutkan', 'disebutkannya', 'disini', 'disinilah', 'ditambahkan', 'ditandaskan', 'ditanya', 'ditanyai', 'ditanyakan', 'ditegaskan', 'ditujukan', 'ditunjuk', 'ditunjuki', 'ditunjukkan', 'ditunjukkannya', 'ditunjuknya', 'dituturkan', 'dituturkannya', 'diucapkan', 'diucapkannya', 'diungkapkan', 'dong', 'dua', 'dulu', 'empat', 'enggak', 'enggaknya', 'entah', 'entahlah', 'guna', 'gunakan', 'hal', 'hampir', 'hanya', 'hanyalah', 'hari', 'harus', 'haruslah', 'harusnya', 'hendak', 'hendaklah', 'hendaknya', 'hingga', 'ia', 'ialah', 'ibarat', 'ibaratkan', 'ibaratnya', 'ibu', 'ikut', 'ingat', 'ingat-ingat', 'ingin', 'inginkah', 'inginkan', 'ini', 'inikah', 'inilah', 'itu', 'itukah', 'itulah', 'jadi', 'jadilah', 'jadinya', 'jangan', 'jangankan', 'janganlah', 'jauh', 'jawab', 'jawaban', 'jawabnya', 'jelas', 'jelaskan', 'jelaslah', 'jelasnya', 'jika', 'jikalau', 'juga', 'jumlah', 'jumlahnya', 'justru', 'kala', 'kalau', 'kalaulah', 'kalaupun', 'kalian', 'kami', 'kamilah', 'kamu', 'kamulah', 'kan', 'kapan', 'kapankah', 'kapanpun', 'karena', 'karenanya', 'kasus', 'kata', 'katakan', 'katakanlah', 'katanya', 'ke', 'keadaan', 'kebetulan', 'kecil', 'kedua', 'keduanya', 'keinginan', 'kelamaan', 'kelihatan', 'kelihatannya', 'kelima', 'keluar', 'kembali', 'kemudian', 'kemungkinan', 'kemungkinannya', 'kenapa', 'kepada', 'kepadanya', 'kesampaian', 'keseluruhan', 'keseluruhannya', 'keterlaluan', 'ketika', 'khususnya', 'kini', 'kinilah', 'kira', 'kira-kira', 'kiranya', 'kita', 'kitalah', 'kok', 'kurang', 'lagi', 'lagian', 'lah', 'lain', 'lainnya', 'lalu' ...

# %%
# text cleaning here
def clean_text(text):

  text = text.lower()

  text = re.sub(r"[^\w\s]", "", text)

  text = remove_metadata(text)

  # Tokenization
  tokens = word_tokenize(text)

  # Normalize
  tokens = [normalize_suffix(word) for word in tokens]

  stopwords_list = stopwords.words("indonesian")

  tokens = [t for t in tokens if t not in stopwords_list]

  return tokens

cleaned_text = clean_text(article)

print(cleaned_text[:4000])
# Out:
# ['bupati', 'pekalongan', 'fadia', 'arafiq', 'anak', 'intervensi', 'kadis', 'pakai', 'jasa', 'perusahaan', 'tim', 'redaksi', 'jakarta', 'komisi', 'pemberantasan', 'korupsi', 'kpk', 'bupati', 'pekalongan', 'fadia', 'arafiq', 'anak', 'menjabat', 'anggota', 'dprd', 'muhammad', 'sabiq', 'ashraff', 'orang', 'kepercayaan', 'diduga', 'intervensi', 'sejum', 'perangkat', 'daerah', 'pemkab', 'pekalongan', 'memakai', 'perusahaan', 'pt', 'rnb', 'raja', 'nusantara', 'berjaya', 'pengadaan', 'barang', 'jasa', 'outsourcing', 'deputi', 'penindakan', 'eksekusi', 'kpk', 'asep', 'guntur', 'rahayu', 'mengumumkan', 'status', 'tersangka', 'fadia', 'arafiq', 'terkait', 'pengadaan', 'barang', 'jasa', 'outsourcing', 'lingkungan', 'pemkab', 'pekalongan', 'periode', '2024', 'far', 'fadia', 'arafiq', 'anak', 'muhammad', 'sabiq', 'ashraff', 'orang', 'kepercayaan', 'diduga', 'intervensi', 'kepala', 'dinas', 'memenangkan', 'pt', 'rnb', 'pengadaan', 'jasa', 'outsourcing', 'sejum', 'dinas', 'kecamatan', 'rumah', 'sakit', 'daerah', 'rsud', 'kabupaten', 'pekalongan', 'asep', 'konferensi', 'pers', 'gedung', 'merah', 'putih', 'jakarta', 'rabu', '432026', 'baca', 'fadia', 'arafiq', 'tempatkan', 'orang', 'kepercayaan', 'perusahaan', 'menang', 'proyek', 'pekalongan', 'asep', 'perusahaan', 'mengajukan', 'penawaran', 'pengadaan', 'nilai', 'rendah', 'perangkat', 'daerah', 'memenangkan', 'perusahaan', 'pt', 'rnb', 'berpotensi', 'menimbulkan', 'kerugian', 'keuangan', 'negara', 'asep', 'perangkat', 'daerah', 'pengadaan', 'menyerahkan', 'harga', 'perkiraan', 'hps', 'pt', 'rnb', 'pt', 'rnb', 'menyesuaikan', 'nilai', 'penawaran', 'mendekati', 'angka', 'hps', 'melanggar', 'prosedur', 'proses', 'pengadaan', 'barang', 'jasa', 'asep', '2025', 'pt', 'rnb', 'mendominasi', 'proyek', 'pengadaan', 'barang', 'jasa', 'pbj', 'pemkab', 'pekalongan', 'pengadaan', 'jasa', 'outsourcing', '17', 'perangkat', 'daerah', '3', 'rsud', '1', 'kecamatan', 'baca', 'dominasi', 'proyek', 'outsourcing', 'keluarga', 'bupati', 'pekalongan', 'fadia', 'arafiq', 'kantongi', 'untung', 'rp', '19', 'miliar', '2023', '2026', 'transaksi', 'masuk', 'pt', 'rnb', 'senilai', 'rp46', 'miliar', 'bersumber', 'kontrak', 'pt', 'rnb', 'perangkat', 'daerah', 'pemkab', 'pekalongan', 'uang', 'pembayaran', 'gaji', 'pegawai', 'outsourcing', 'ha', 'rp22', 'miliar', 'sisa', 'dinikmati', 'dibagikan', 'keluarga', 'bupati', 'total', 'mencapai', 'rp19', 'miliar', '40', 'persen', 'total', 'transaksi', 'rincian', 'bupati', 'pekalongan', 'fadia', 'arafiq', 'rp', '55', 'miliar', 'muhammad', 'sabiq', 'ashraff', 'suami', 'bupati', 'rp', '11', 'miliar', 'rul', 'bayatun', 'direktur', 'pt', 'rnb', 'rp', '23', 'miliar', 'muhammad', 'sabiq', 'ashraff', 'anak', 'bupati', 'rp', '46', 'miliar', 'mehnaz', 'anak', 'bupati', 'rp', '25', 'miliar', 'penarikan', 'tunai', 'rp3', 'miliar', 'asep', 'pengelolaan', 'distribusi', 'uang', 'diatur', 'fadia', 'arafiq', 'pengaturan', 'komunikasi', 'wa', 'grup', 'bernama', 'belanja', 'rsud', 'staf', 'pengambilan', 'uang', 'bupati', 'staf', 'melaporkan', 'mendokumentasikan', 'mengirimkan', 'wa', 'grup', 'penyidik', 'menelusuri', 'perusahaan', 'modus', 'penerimaan', 'perbuatan', 'fadia', 'disangkakan', 'te', 'tindak', 'pidana', 'korupsi', 'diatur', 'pasal', '12', 'huruf', 'i', 'pasal', '12', 'b', 'undangundang', 'ri', 'nomor', '31', '1999', 'pemberantasan', 'tindak', 'pidana', 'korupsi', 'te', 'diubah', 'undangundang', 'ri', 'nomor', '20', '2001', 'perubahan', 'undangundang', 'ri', 'nomor', '31', '1999', 'pemberantasan', 'tindak', 'pidana', 'korupsi', 'jo', 'pasal', '127', 'ayat', '1', 'undangundang', 'nomor', '1', '2023', 'kitab', 'undangundang', 'hukum', 'pidana', 'kuhp', 'copyright', '2008', '2026', 'pt', 'kompas', 'cyber', 'media', 'kompas', 'gramedia', 'digital', 'group', 'all', 'rights', 'reserved']

# %%
#do normalization here

# %%
#do remove footer here

# %%
# normalize suffix

# %%
# remove metadata

# %% [markdown]
# Dalam Natural Language Processing (NLP), teks yang diperoleh dari internet biasanya masih mengandung banyak noise seperti:
#
# - URL
#
# - angka
#
# - tanda baca
#
# - metadata berita
#
# - footer website
#
# - kata tidak penting (stopwords)
#
# Oleh karena itu, sebelum melakukan analisis linguistik seperti POS Tagging, Named Entity Recognition, atau Dependency Parsing, perlu dilakukan tahap text preprocessing atau text cleaning.
#
# Tujuan utama text cleaning adalah:
#
# - membersihkan teks dari noise
#
# - menormalkan kata
#
# - mempersiapkan data agar siap diproses oleh model NLP

# %% [markdown]
# ## Alur text Preprocessing yang akan dilakukan ##
#
# Raw Article ->
# Lowercase ->
# Remove URL ->
# Remove Numbers ->
# Remove Metadata ->
# Remove Punctuation ->
# Tokenization ->
# Suffix Normalization ->
# Word Normalization ->
# Stopword Removal ->
# Footer Removal ->
# Clean Tokens

# %%
#write clean text function
# Out:
# ['bupati', 'pekalongan', 'fadia', 'arafiq', 'anak', 'intervensi', 'kepala dinas', 'pakai', 'jasa', 'perusahaan', 'com', 'komisi', 'pemberantasan', 'korupsi', 'kpk', 'bupati', 'pekalongan', 'fadia', 'arafiq', 'anak', 'menjabat', 'anggota', 'dprd', 'muhammad', 'sabiq', 'ashraff', 'orang', 'kepercayaan', 'diduga', 'intervensi', 'sejum', 'perangkat', 'daerah', 'pemerintah kabupaten', 'pekalongan', 'memakai', 'perusahaan', 'pt', 'rnb', 'raja', 'nusantara', 'berjaya', 'pengadaan', 'barang', 'jasa', 'outsourcing', 'deputi', 'penindakan', 'eksekusi', 'kpk', 'asep', 'guntur', 'rahayu', 'mengumumkan', 'status', 'tersangka', 'fadia', 'arafiq', 'terkait', 'pengadaan', 'barang', 'jasa', 'outsourcing', 'lingkungan', 'pemerintah kabupaten', 'pekalongan', 'periode', 'far', 'fadia', 'arafiq', 'anak', 'muhammad', 'sabiq', 'ashraff', 'orang', 'kepercayaan', 'diduga', 'intervensi', 'kepala', 'dinas', 'memenangkan', 'pt', 'rnb', 'pengadaan', 'jasa', 'outsourcing', 'sejum', 'dinas', 'kecamatan', 'rumah', 'sakit', 'daerah', 'rsud', 'kabupaten', 'pekalongan', 'asep', 'konferensi', 'pers', 'gedung', 'merah', 'putih', 'jakarta', 'rabu']

# %% [markdown]
# ## Word Frequency Analysis ##
#
# Setelah proses text cleaning dan preprocessing selesai dilakukan, langkah selanjutnya adalah melakukan analisis frekuensi kata (Word Frequency Analysis).
#
# Tujuan dari analisis ini adalah untuk mengetahui kata-kata yang paling sering muncul dalam sebuah teks atau dokumen.
#
# Kata yang sering muncul biasanya dapat menggambarkan topik utama atau tema dari teks yang dianalisis.
#
# Word frequency adalah metode sederhana dalam text mining yang menghitung berapa kali sebuah kata muncul dalam sebuah dokumen.
#
# Word frequency memiliki berbagai manfaat dalam analisis teks, antara lain:
#
# 1.  Menemukan topik utama dalam dokumen
#
# 2.  Membantu proses keyword extraction
#
# 3.  Menjadi dasar pembuatan word cloud
#
# 4. Membantu proses topic modeling
#
# 5. Digunakan dalam berbagai metode text mining

# %%
#write word frequency analysis

from collections import Counter

freq = Counter(cleaned_text)

print(freq.most_common(10))
# Out:
# [('pekalongan', 10), ('pt', 10), ('miliar', 10), ('bupati', 9), ('fadia', 9), ('rnb', 9), ('arafiq', 8), ('pengadaan', 8), ('jasa', 7), ('perusahaan', 6)]

# %%
#write word frequency analysis

text_clean = " ".join(cleaned_text)

wordcloud = WordCloud(width = 800, height = 800,
                      background_color="white").generate(text_clean)
plt.figure(figsize=(8,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Word Cloud")
plt.show()

# %%
#check the words that often appear
# Out:
# Keywords: ['pekalongan', 'fadia', 'arafiq', 'jasa', 'anak', 'intervensi', 'pengadaan', 'outsourcing', 'bupati', 'perusahaan', 'kpk', 'muhammad', 'sabiq', 'ashraff', 'orang']

# %% [markdown]
# ---
# # Linguistic Processing #
#
# ---

# %% [markdown]
# # Part-of-Speech Tagging Menggunakan Stanza
#
# Setelah tahap **text preprocessing** selesai dilakukan, langkah selanjutnya dalam pipeline **Natural Language Processing (NLP)** adalah melakukan **analisis linguistik**. Salah satu teknik yang umum digunakan adalah **Part-of-Speech (POS) Tagging**.
#
# **Part-of-Speech Tagging** adalah proses memberikan label kelas kata pada setiap kata dalam kalimat. Label ini menunjukkan fungsi gramatikal suatu kata dalam struktur kalimat.
#
# POS tagging memiliki berbagai manfaat dalam analisis NLP, antara lain:
#
# 1. Memahami struktur kalimat
#
# 2. Membantu proses dependency parsing
#
# 3. Membantu named entity recognition
#
# 4. Digunakan dalam information extraction
#
# 5. Digunakan dalam machine translation
#
# Contoh kelas kata:
#
# | Kelas Kata | Contoh |
# |------------|--------|
# | Noun (kata benda) | buku, rumah |
# | Verb (kata kerja) | makan, berjalan |
# | Adjective (kata sifat) | besar, cepat |
# | Adverb (kata keterangan) | sangat, cepat |
#
# Pada eksperimen ini digunakan library **Stanza**, yaitu library NLP yang dikembangkan oleh **Stanford NLP Group**.
#
# ---
#
# # Library Stanza
#
# **Stanza** merupakan toolkit NLP yang menyediakan berbagai fitur pemrosesan bahasa alami seperti:
#
# - Tokenization
# - Part-of-Speech Tagging
# - Lemmatization
# - Named Entity Recognition (NER)
# - Dependency Parsing
#
# Stanza mendukung berbagai bahasa termasuk **Bahasa Indonesia**.
#
# ---
#
# # Mengunduh Model Bahasa Indonesia
#
# ```python
# stanza.download("id")
# ```
#
# ### Universal POS Tag
#
# Stanza menggunakan sistem **Universal POS Tags (UPOS)** untuk memberi label kelas kata pada setiap token dalam teks.
#
# Berikut beberapa tag yang sering muncul:
#
# | Tag  | Arti |
# |------|------|
# | NOUN | Kata benda |
# | VERB | Kata kerja |
# | PROPN | Proper noun (nama orang/tempat) |
# | ADJ | Kata sifat |
# | ADV | Kata keterangan |
# | ADP | Preposisi |
# | PRON | Kata ganti |

# %%
# Do POS Tagging here

stanza.download("id")

nlp = stanza.Pipeline("id")

doc = nlp(article)

for sentence in doc.sentences:
  for word in sentence.words:
    print(word.text, word.upos)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/resources.json
# INFO:stanza:Downloading default packages for language: id (Indonesian) ...
# INFO:stanza:File exists: /root/.cache/stanza/1.11.0/resources/id/default.zip
# INFO:stanza:Finished downloading models and saved to /root/.cache/stanza/1.11.0/resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/resources.json
# INFO:stanza:Loading these models for language: id (Indonesian):
# ===============================
# | Processor    | Package      |
# -------------------------------
# | tokenize     | gsd          |
# | mwt          | gsd          |
# | pos          | gsd_charlm   |
# | lemma        | gsd_nocharlm |
# | constituency | icon_charlm  |
# | depparse     | gsd_charlm   |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: constituency
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# Bupati NOUN
# Pekalongan PROPN
# Fadia PROPN
# Arafiq PROPN
# dan CCONJ
# Anak NOUN
# nya PRON
# Intervensi PROPN
# Kadis PROPN
# untuk ADP
# Pakai PROPN
# Jasa PROPN
# Perusahaan PROPN
# Mereka PRON
# Tim PROPN
# Redaksi PROPN
# JAKARTA PROPN
# , PUNCT
# KOMPAS.com PROPN
# - PUNCT
# Komisi PROPN
# Pemberantasan PROPN
# Korupsi PROPN
# ( PUNCT
# KPK PROPN
# ) PUNCT
# mengatakan VERB
# , PUNCT
# Bupati NOUN
# Pekalongan PROPN
# Fadia PROPN
# Arafiq PROPN
# melalui VERB
# anak NOUN
# nya PRON
# yang PRON
# menjabat VERB
# sebagai ADP
# Anggota PROPN
# DPRD PROPN
# , PUNCT
# Muhammad PROPN
# Sabiq PROPN
# Ashraff PROPN
# , PUNCT
# dan CCONJ
# orang NOUN
# kepercayaan NOUN
# nya PRON
# diduga ADV
# melakukan VERB
# intervensi NOUN
# kepada ADP
# sejumlah DET
# Perangkat PROPN
# Daerah PROPN
# Pemkab PROPN
# Pekalongan PROPN
# agar SCONJ
# memakai VERB
# perusahaan NOUN
# mereka PRON
# yakni ADP
# PT PROPN
# RNB PROPN
# ( PUNCT
# Raja PROPN
# Nusantara PROPN
# Berjaya PROPN
# ) PUNCT
# untuk ADP
# pengadaan NOUN
# barang NOUN
# dan CCONJ
# jasa NOUN
# outsourcing NOUN
# . PUNCT
# Hal NOUN
# tersebut DET
# disampaikan VERB
# Deputi PROPN
# Penindakan PROPN
# dan CCONJ
# Eksekusi PROPN
# KPK PROPN
# Asep PROPN
# Guntur PROPN
# Rahayu PROPN
# saat SCONJ
# mengumumkan VERB
# status NOUN
# tersangka NOUN
# terhadap ADP
# Fadia PROPN
# Arafiq PROPN
# terkait VERB
# kasus NOUN
# pengadaan NOUN
# barang NOUN
# dan CCONJ
# jasa NOUN
# outsourcing NOUN
# di ADP
# lingkungan NOUN
# Pemkab PROPN
# Pekalongan PROPN
# . PUNCT
# “ PUNCT
# Pada ADP
# periode NOUN
# tersebut DET
# ( PUNCT
# 2024 NUM
# ) PUNCT
# , PUNCT
# FAR PROPN
# ( PUNCT
# Fadia PROPN
# Arafiq PROPN
# ) PUNCT
# melalui ADP
# anak NOUN
# nya PRON
# , PUNCT
# ( PUNCT
# Muhammad PROPN
# Sabiq PROPN
# Ashraff PROPN
# ) PUNCT
# dan CCONJ
# orang NOUN
# kepercayaan NOUN
# nya PRON
# diduga ADV
# melakukan VERB
# intervensi NOUN
# kepada ADP
# para DET
# Kepala PROPN
# Dinas PROPN
# agar SCONJ
# memenangkan VERB
# PT PROPN
# RNB PROPN
# untuk ADP
# pengadaan NOUN
# jasa NOUN
# outsourcing NOUN
# di ADP
# sejumlah DET
# dinas NOUN
# , PUNCT
# kecamatan NOUN
# , PUNCT
# hingga ADP
# Rumah PROPN
# Sakit PROPN
# Umum PROPN
# Daerah PROPN
# ( PUNCT
# RSUD PROPN
# ) PUNCT
# di ADP
# Kabupaten PROPN
# Pekalongan PROPN
# , PUNCT
# ” PUNCT
# kata VERB
# Asep PROPN
# dalam ADP
# konferensi NOUN
# pers ADJ
# di ADP
# Gedung PROPN
# Merah PROPN
# Putih PROPN
# , PUNCT
# Jakarta PROPN
# , PUNCT
# Rabu PROPN
# ( PUNCT
# 4/3/ NUM
# 2026 NUM
# ) PUNCT
# . PUNCT
# Baca VERB
# juga ADV
# : PUNCT
# Fadia PROPN
# Arafiq PROPN
# Tempatkan VERB
# Orang NOUN
# Kepercayaan PROPN
# di ADP
# Perusahaan PROPN
# yang PRON
# Menang PROPN
# Proyek PROPN
# di ADP
# Pekalongan PROPN
# Asep PROPN
# mengatakan VERB
# , PUNCT
# meskipun SCONJ
# ada VERB
# perusahaan NOUN
# lain ADJ
# yang PRON
# mengajukan VERB
# penawaran NOUN
# pengadaan NOUN
# dengan ADP
# nilai NOUN
# yang PRON
# rendah ADJ
# , PUNCT
# para DET
# perangkat NOUN
# daerah NOUN
# harus AUX
# memenangkan VERB
# “ PUNCT
# perusahaan NOUN
# ibu NOUN
# ” PUNCT
# PT PROPN
# RNB PROPN
# . PUNCT
# “ PUNCT
# Sehingga SCONJ
# hal NOUN
# itu DET
# juga ADV
# berpotensi VERB
# dapat AUX
# menimbulkan VERB
# kerugian NOUN
# keuangan NOUN
# negara NOUN
# , PUNCT
# ” PUNCT
# ujar NOUN
# nya DET
# . PUNCT
# Asep PROPN
# mengatakan VERB
# , PUNCT
# setiap DET
# perangkat NOUN
# daerah NOUN
# yang PRON
# akan AUX
# melakukan VERB
# pengadaan NOUN
# diminta VERB
# menyerahkan VERB
# Harga PROPN
# Perkiraan PROPN
# Sendiri PROPN
# ( PUNCT
# HPS PROPN
# ) PUNCT
# kepada ADP
# PT PROPN
# RNB PROPN
# di ADP
# awal ADJ
# , PUNCT
# agar SCONJ
# PT PROPN
# RNB PROPN
# bisa AUX
# menyesuaikan VERB
# nilai NOUN
# penawaran NOUN
# yang PRON
# mendekati VERB
# angka NOUN
# HPS PROPN
# . PUNCT
# “ PUNCT
# Hal NOUN
# itu DET
# melanggar VERB
# prosedur NOUN
# dalam ADP
# proses NOUN
# pengadaan NOUN
# barang NOUN
# dan CCONJ
# jasa NOUN
# , PUNCT
# ” PUNCT
# tutur NOUN
# nya PRON
# . PUNCT
# Asep PROPN
# juga ADV
# mengungkapkan VERB
# , PUNCT
# sepanjang ADP
# tahun NOUN
# 2025 NUM
# , PUNCT
# PT PROPN
# RNB PROPN
# mendominasi VERB
# proyek NOUN
# pengadaan NOUN
# barang NOUN
# dan CCONJ
# jasa NOUN
# ( PUNCT
# PBJ PROPN
# ) PUNCT
# di ADP
# Pemkab PROPN
# Pekalongan PROPN
# dengan SCONJ
# mengerjakan VERB
# pengadaan NOUN
# jasa NOUN
# outsourcing NOUN
# di ADP
# 17 NUM
# Perangkat PROPN
# Daerah PROPN
# , PUNCT
# 3 NUM
# RSUD PROPN
# , PUNCT
# dan CCONJ
# 1 NUM
# Kecamatan PROPN
# . PUNCT
# Baca VERB
# juga ADV
# : PUNCT
# Dominasi PROPN
# Proyek PROPN
# Outsourcing PROPN
# , PUNCT
# Keluarga PROPN
# Bupati NOUN
# Pekalongan PROPN
# Fadia PROPN
# Arafiq PROPN
# Kantongi PROPN
# Untung PROPN
# Rp PROPN
# 19 NUM
# Miliar NUM
# Selain ADP
# itu DET
# , PUNCT
# sepanjang ADP
# tahun NOUN
# 2023 NUM
# - PUNCT
# 2026 NUM
# , PUNCT
# terdapat VERB
# transaksi NOUN
# masuk VERB
# ke ADP
# PT PROPN
# RNB PROPN
# senilai ADP
# Rp46 NUM
# miliar NOUN
# yang PRON
# bersumber VERB
# dari ADP
# kontrak NOUN
# antara ADP
# PT PROPN
# RNB PROPN
# dan CCONJ
# Perangkat PROPN
# Daerah PROPN
# di ADP
# Pemkab PROPN
# Pekalongan PROPN
# . PUNCT
# Kemudian ADV
# dari ADP
# uang NOUN
# tersebut DET
# , PUNCT
# yang PRON
# digunakan VERB
# untuk ADP
# pembayaran NOUN
# gaji NOUN
# pegawai NOUN
# outsourcing NOUN
# hanya ADV
# sebesar ADP
# Rp22 NUM
# miliar NOUN
# . PUNCT
# Sisa PROPN
# diantara ADP
# nya PRON
# , PUNCT
# dinikmati VERB
# dan CCONJ
# dibagikan VERB
# kepada ADP
# keluarga NOUN
# Bupati NOUN
# dengan ADP
# total NOUN
# mencapai VERB
# Rp19 NUM
# miliar NOUN
# ( PUNCT
# sekitar ADP
# 40 NUM
# persen NOUN
# ) PUNCT
# dari ADP
# total NOUN
# transaksi NOUN
# . PUNCT
# Rincian NOUN
# nya PRON
# , PUNCT
# Bupati NOUN
# Pekalongan PROPN
# Fadia PROPN
# Arafiq PROPN
# sebesar ADP
# Rp PROPN
# 5,5 NUM
# miliar NOUN
# ; PUNCT
# Muhammad PROPN
# Sabiq PROPN
# Ashraff PROPN
# ( PUNCT
# suami NOUN
# bupati NOUN
# ) PUNCT
# Rp PROPN
# 1,1 NUM
# miliar NOUN
# ; PUNCT
# Rul PROPN
# Bayatun PROPN
# selaku VERB
# Direktur PROPN
# PT PROPN
# RNB PROPN
# Rp PROPN
# 2,3 NUM
# miliar NOUN
# ; PUNCT
# Muhammad PROPN
# Sabiq PROPN
# Ashraff PROPN
# ( PUNCT
# anak NOUN
# bupati NOUN
# ) PUNCT
# Rp PROPN
# 4,6 NUM
# miliar NOUN
# ; PUNCT
# Mehnaz PROPN
# ( PUNCT
# anak NOUN
# bupati NOUN
# ) PUNCT
# Rp PROPN
# 2,5 NUM
# miliar NOUN
# ; PUNCT
# serta CCONJ
# dilakukan VERB
# penarikan NOUN
# tunai NOUN
# sebesar ADP
# Rp3 NUM
# miliar NOUN
# . PUNCT
# Asep PROPN
# mengatakan VERB
# , PUNCT
# pengelolaan NOUN
# dan CCONJ
# distribusi NOUN
# uang NOUN
# tersebut DET
# diatur VERB
# oleh ADP
# Fadia PROPN
# Arafiq PROPN
# . PUNCT
# Ia PRON
# mengatakan VERB
# , PUNCT
# pengaturan NOUN
# dilakukan VERB
# melalui ADP
# komunikasi NOUN
# WA PROPN
# Grup PROPN
# bernama VERB
# “ PUNCT
# Belanja PROPN
# RSUD PROPN
# ” PUNCT
# bersama ADP
# para DET
# staf NOUN
# nya PRON
# . PUNCT
# “ PUNCT
# Setiap DET
# pengambilan NOUN
# uang NOUN
# untuk ADP
# Bupati NOUN
# , PUNCT
# staf NOUN
# selalu ADV
# melaporkan VERB
# , PUNCT
# mendokumentasikan VERB
# , PUNCT
# dan CCONJ
# mengirimkan VERB
# nya PRON
# melalui ADP
# WA PROPN
# Grup PROPN
# tersebut DET
# . PUNCT
# Penyidik PROPN
# juga ADV
# masih ADV
# akan AUX
# terus ADV
# menelusuri VERB
# apa ADV
# kah PART
# perusahaan NOUN
# ini DET
# juga ADV
# digunakan VERB
# untuk SCONJ
# melakukan VERB
# modus NOUN
# dalam ADP
# penerimaan NOUN
# lainnya ADJ
# , PUNCT
# ” PUNCT
# ucap VERB
# dia PRON
# . PUNCT
# Atas ADP
# perbuatan NOUN
# nya PRON
# , PUNCT
# Fadia PROPN
# disangkakan VERB
# telah AUX
# melakukan VERB
# tindak NOUN
# pidana NOUN
# korupsi NOUN
# sebagaimana SCONJ
# diatur VERB
# dalam ADP
# Pasal NOUN
# 12 NUM
# huruf NOUN
# i NOUN
# dan CCONJ
# Pasal NOUN
# 12 NUM
# B NOUN
# Undang-Undang NOUN
# RI PROPN
# Nomor NOUN
# 31 NUM
# Tahun PROPN
# 1999 NUM
# tentang ADP
# Pemberantasan PROPN
# Tindak PROPN
# Pidana PROPN
# Korupsi PROPN
# sebagaimana SCONJ
# telah AUX
# diubah VERB
# dengan ADP
# Undang-Undang NOUN
# RI PROPN
# Nomor NOUN
# 20 NUM
# Tahun PROPN
# 2001 NUM
# tentang ADP
# Perubahan PROPN
# Atas ADP
# Undang-Undang NOUN
# RI PROPN
# Nomor NOUN
# 31 NUM
# Tahun PROPN
# 1999 NUM
# tentang ADP
# Pemberantasan PROPN
# Tindak PROPN
# Pidana PROPN
# Korupsi PROPN
# Jo PROPN
# . PUNCT
# Pasal NOUN
# 127 NUM
# ayat NOUN
# ( PUNCT
# 1 NUM
# ) PUNCT
# Undang-Undang NOUN
# Nomor NOUN
# 1 NUM
# Tahun PROPN
# 2023 NUM
# tentang ADP
# Kitab PROPN
# Undang-Undang PROPN
# Hukum PROPN
# Pidana PROPN
# ( PUNCT
# KUHP PROPN
# ) PUNCT
# . PUNCT
# Copyright PROPN
# 2008 NUM
# - PUNCT
# 2026 NUM
# PT PROPN
# . PUNCT
# Kompas PROPN
# Cyber PROPN
# Media PROPN
# ( PUNCT
# Kompas PROPN
# Gramedia PROPN
# Digital PROPN
# Group PROPN
# ) PUNCT
# . PUNCT
# All PROPN
# Rights PROPN
# Reserved PROPN
# . PUNCT

# %%
# !pip install spacy
# !python -m spacy download xx_ent_wiki_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.1.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting xx-ent-wiki-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/xx_ent_wiki_sm-3.8.0/xx_ent_wiki_sm-3.8.0-py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 84.1 MB/s eta 0:00:00
# Installing collected packages: xx-ent-wiki-sm
# Successfully installed xx-ent-wiki-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('xx_ent_wiki_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# # Named Entity Recognition (NER)
#
# Setelah melakukan proses **Part-of-Speech Tagging**, langkah selanjutnya dalam pipeline **Natural Language Processing (NLP)** adalah melakukan **Named Entity Recognition (NER)**.
#
# Named Entity Recognition adalah teknik dalam NLP yang digunakan untuk **mengidentifikasi dan mengklasifikasikan entitas penting dalam teks**.
#
# Entitas yang biasanya dideteksi antara lain:
#
# - Nama orang
# - Nama organisasi
# - Nama lokasi
# - Tanggal
# - Nilai uang
# - Persentase
#
# NER sangat penting dalam analisis teks karena membantu mengekstrak **informasi penting dari dokumen secara otomatis**.
#
# ---
#
# ## Manfaat Named Entity Recognition ##
#
# Named Entity Recognition memiliki berbagai manfaat dalam analisis teks, antara lain:
#
# 1. Mengekstrak informasi penting dari dokumen
#
# 2. Mengidentifikasi tokoh dalam berita
#
# 3. Menemukan organisasi atau institusi yang terlibat
#
# 4. Menganalisis hubungan antar entitas
#
# 5. Digunakan dalam sistem information extraction

# %%
#Named Entity Recognition (NER)
import spacy

nlp = spacy.load("xx_ent_wiki_sm")

doc = nlp(article)

for ent in doc.ents:
  print(ent.text, ent.label_)
# Out:
# Pekalongan Fadia Arafiq PER
# Anaknya Intervensi Kadis PER
# Pakai Jasa Perusahaan PER
# Tim Redaksi PER
# KOMPAS.com - Komisi ORG
# KPK ORG
# Bupati Pekalongan Fadia Arafiq PER
# Anggota DPRD PER
# Muhammad Sabiq Ashraff PER
# Daerah Pemkab Pekalongan PER
# PT RNB ORG
# Raja Nusantara Berjaya PER
# Hal PER
# Deputi Penindakan PER
# Fadia Arafiq PER
# Pemkab Pekalongan PER
# FAR ORG
# Fadia Arafiq PER
# Muhammad Sabiq Ashraff PER
# Kepala Dinas LOC
# PT RNB ORG
# sejumlah dinas PER
# Rumah Sakit Umum Daerah PER
# RSUD ORG
# Kabupaten Pekalongan PER
# Asep PER
# Merah Putih PER
# Jakarta LOC
# Rabu LOC
# Baca PER
# Fadia Arafiq Tempatkan PER
# Menang Proyek PER
# Pekalongan Asep PER
# yang mengajukan PER
# yang rendah PER
# PT RNB ORG
# Sehingga PER
# menimbulkan kerugian keuangan negara PER
# daerah yang PER
# Harga Perkiraan Sendiri PER
# HPS ORG
# PT RNB ORG
# PT RNB ORG
# HPS ORG
# Hal PER
# PT RNB ORG
# PBJ ORG
# Pemkab Pekalongan PER
# Perangkat Daerah MISC
# Baca PER
# Dominasi Proyek Outsourcing PER
# Keluarga Bupati PER
# PT RNB ORG
# Rp46 MISC
# PT RNB ORG
# Daerah di Pemkab Pekalongan PER
# Kemudian PER
# yang digunakan PER
# Rp22 MISC
# Sisa PER
# Bupati MISC
# Rp19 MISC
# Rinciannya LOC
# Bupati Pekalongan Fadia Arafiq LOC
# Rp LOC
# Muhammad Sabiq Ashraff PER
# Rp LOC
# Rul Bayatun PER
# PT RNB Rp ORG
# Muhammad Sabiq Ashraff PER
# Mehnaz PER
# Rp LOC
# Rp3 MISC
# Fadia Arafiq PER
# WA Grup MISC
# Belanja RSUD MISC
# Bupati MISC
# WA Grup MISC
# Fadia LOC
# Pasal 12 MISC
# Pasal 12 MISC
# Pemberantasan LOC
# Tindak Pidana Korupsi PER
# Undang-Undang RI Nomor ORG
# Perubahan Atas Undang-Undang RI PER
# Pemberantasan LOC
# Tindak Pidana Korupsi Jo PER
# Kitab Undang-Undang Hukum Pidana LOC
# KUHP ORG
# PT ORG
# Kompas Cyber Media PER
# Kompas Gramedia Digital Group ORG
# Rights Reserved ORG

# %% [markdown]
# # Depedency parsing

# %% [markdown]
# # Dependency Parsing dalam NLP
#
# ## Pengertian
#
# **Dependency Parsing** adalah teknik dalam **Natural Language Processing (NLP)** yang digunakan untuk menganalisis **hubungan tata bahasa antar kata dalam sebuah kalimat**.
#
# Metode ini menentukan hubungan antara:
#
# - **Head** : kata utama
# - **Dependent** : kata yang bergantung pada head
# - **Dependency Relation** : jenis hubungan antar kata
#
# ---
#
# ## Contoh
#
# Kalimat:
#
# The cat eats fish
#
# struktur depedency"
#
#      eats
#
#     /    \
#
#     cat    fish
#
#     /
#
#
#
# Hubungan:
#
# | Kata | Head | Relasi |
# |-----|-----|------|
# | eats | ROOT | root |
# | cat | eats | nsubj |
# | fish | eats | obj |
# | The | cat | det |
#
# ---
#
# ## Fungsi Dependency Parsing
#
# Dependency parsing digunakan untuk:
#
# - **Information Extraction**
# - **Question Answering**
# - **Machine Translation**
# - **Sentiment Analysis**

# %%
# Depedency parsing
nlp = spacy.load("en_core_web_sm")

doc = nlp(article)

for sentence in doc.sents:
  for word in sentence:
    print(word.text,"->", word.dep_,"->", word.head.text)
# Out:
# Bupati -> compound -> Fadia
# Pekalongan -> compound -> Fadia
# Fadia -> compound -> untuk
# Arafiq -> compound -> Intervensi
# dan -> compound -> Intervensi
# Anaknya -> compound -> Intervensi
# Intervensi -> compound -> Kadis
# Kadis -> compound -> untuk
# untuk -> nsubj -> sebagai
# Pakai -> compound -> Jasa
# Jasa -> compound -> Mereka
# Perusahaan -> compound -> Mereka
# Mereka -> appos -> untuk
# Tim -> compound -> Redaksi
# Redaksi -> compound -> JAKARTA
# JAKARTA -> appos -> untuk
# , -> punct -> JAKARTA
# KOMPAS.com -> compound -> Komisi
# - -> punct -> Komisi
# Komisi -> compound -> Korupsi
# Pemberantasan -> compound -> Korupsi
# Korupsi -> nmod -> mengatakan
# ( -> punct -> Korupsi
# KPK -> nmod -> mengatakan
# ) -> punct -> mengatakan
# mengatakan -> appos -> JAKARTA
# , -> punct -> JAKARTA
# Bupati -> compound -> menjabat
# Pekalongan -> compound -> Fadia
# Fadia -> compound -> menjabat
# Arafiq -> compound -> menjabat
# melalui -> compound -> menjabat
# anaknya -> compound -> menjabat
# yang -> compound -> menjabat
# menjabat -> appos -> JAKARTA
# sebagai -> ROOT -> sebagai
# Anggota -> compound -> DPRD
# DPRD -> dobj -> sebagai
# , -> punct -> DPRD
# Muhammad -> compound -> Ashraff
# Sabiq -> compound -> Ashraff
# Ashraff -> conj -> DPRD
# , -> punct -> Ashraff
# dan -> compound -> diduga
# orang -> compound -> diduga
# kepercayaannya -> compound -> diduga
# diduga -> compound -> kepada
# melakukan -> compound -> kepada
# intervensi -> compound -> kepada
# kepada -> compound -> sejumlah
# sejumlah -> compound -> mereka
# Perangkat -> compound -> Pekalongan
# Daerah -> compound -> Pekalongan
# Pemkab -> compound -> Pekalongan
# Pekalongan -> compound -> agar
# agar -> compound -> mereka
# memakai -> compound -> mereka
# perusahaan -> compound -> mereka
# mereka -> compound -> RNB
# yakni -> compound -> RNB
# PT -> compound -> RNB
# RNB -> conj -> Ashraff
# ( -> punct -> Ashraff
# Raja -> nmod -> untuk
# Nusantara -> compound -> Berjaya
# Berjaya -> npadvmod -> Raja
# ) -> punct -> Raja
# untuk -> nsubj -> outsourcing
# pengadaan -> compound -> outsourcing
# barang -> compound -> jasa
# dan -> compound -> jasa
# jasa -> compound -> outsourcing
# outsourcing -> ROOT -> outsourcing
# . -> punct -> outsourcing
# Hal -> compound -> tersebut
# tersebut -> nsubj -> disampaikan
# disampaikan -> ROOT -> disampaikan
# Deputi -> compound -> Penindakan
# Penindakan -> compound -> Eksekusi
# dan -> compound -> Eksekusi
# Eksekusi -> dobj -> disampaikan
# KPK -> compound -> Guntur
# Asep -> compound -> Guntur
# Guntur -> compound -> Rahayu
# Rahayu -> nmod -> status
# saat -> appos -> Rahayu
# mengumumkan -> compound -> status
# status -> compound -> terhadap
# tersangka -> amod -> terhadap
# terhadap -> compound -> terkait
# Fadia -> compound -> Arafiq
# Arafiq -> compound -> terkait
# terkait -> compound -> jasa
# kasus -> compound -> jasa
# pengadaan -> compound -> jasa
# barang -> compound -> jasa
# dan -> compound -> jasa
# jasa -> compound -> Pekalongan
# outsourcing -> compound -> Pekalongan
# di -> nmod -> Pekalongan
# lingkungan -> compound -> Pekalongan
# Pemkab -> compound -> Pekalongan
# Pekalongan -> ROOT -> Pekalongan
# . -> punct -> Pekalongan
# “ -> punct -> tersebut
# Pada -> compound -> periode
# periode -> compound -> tersebut
# tersebut -> nmod -> Pekalongan
# ( -> punct -> tersebut
# 2024 -> appos -> tersebut
# ) -> punct -> tersebut
# , -> punct -> tersebut
# FAR -> dep -> tersebut
# ( -> punct -> FAR
# Fadia -> nmod -> Arafiq
# Arafiq -> nmod -> anaknya
# ) -> punct -> anaknya
# melalui -> compound -> anaknya
# anaknya -> appos -> tersebut
# , -> punct -> anaknya
# ( -> punct -> anaknya
# Muhammad -> compound -> Ashraff
# Sabiq -> compound -> Ashraff
# Ashraff -> appos -> anaknya
# ) -> punct -> Ashraff
# dan -> compound -> diduga
# orang -> compound -> diduga
# kepercayaannya -> compound -> diduga
# diduga -> compound -> kepada
# melakukan -> compound -> kepada
# intervensi -> compound -> kepada
# kepada -> compound -> para
# para -> compound -> untuk
# Kepala -> compound -> Dinas
# Dinas -> compound -> agar
# agar -> compound -> memenangkan
# memenangkan -> compound -> untuk
# PT -> compound -> untuk
# RNB -> compound -> untuk
# untuk -> compound -> outsourcing
# pengadaan -> compound -> outsourcing
# jasa -> compound -> outsourcing
# outsourcing -> compound -> dinas
# di -> compound -> dinas
# sejumlah -> compound -> dinas
# dinas -> appos -> tersebut
# , -> punct -> dinas
# kecamatan -> conj -> dinas
# , -> punct -> kecamatan
# hingga -> compound -> Sakit
# Rumah -> compound -> Sakit
# Sakit -> compound -> Daerah
# Umum -> compound -> Daerah
# Daerah -> conj -> kecamatan
# ( -> punct -> RSUD
# RSUD -> appos -> Daerah
# ) -> punct -> RSUD
# di -> compound -> Pekalongan
# Kabupaten -> compound -> Pekalongan
# Pekalongan -> ROOT -> Pekalongan
# , -> punct -> Pekalongan
# ” -> punct -> Pekalongan
# kata -> appos -> Pekalongan
# Asep -> nsubj -> dalam
# dalam -> ROOT -> dalam
# konferensi -> compound -> pers
# pers -> compound -> Putih
# di -> compound -> Putih
# Gedung -> compound -> Putih
# Merah -> compound -> Putih
# Putih -> dobj -> dalam
# , -> punct -> Putih
# Jakarta -> npadvmod -> Putih
# , -> punct -> Jakarta
# Rabu -> conj -> Jakarta
# ( -> punct -> Rabu
# 4/3/2026 -> appos -> Rabu
# ) -> punct -> Rabu
# . -> punct -> dalam
# Baca -> compound -> juga
# juga -> ROOT -> juga
# : -> punct -> juga
# Fadia -> compound -> Arafiq
# Arafiq -> compound -> yang
# Tempatkan -> compound -> Kepercayaan
# Orang -> compound -> Kepercayaan
# Kepercayaan -> compound -> Perusahaan
# di -> compound -> Perusahaan
# Perusahaan -> compound -> yang
# yang -> compound -> mengatakan
# Menang -> compound -> Asep
# Proyek -> nmod -> Asep
# di -> nmod -> Asep
# Pekalongan -> compound -> Asep
# Asep -> compound -> mengatakan
# mengatakan -> appos -> juga
# , -> punct -> mengatakan
# meskipun -> compound -> lain
# ada -> compound -> lain
# perusahaan -> compound -> lain
# lain -> compound -> rendah
# yang -> compound -> rendah
# mengajukan -> compound -> penawaran
# penawaran -> compound -> rendah
# pengadaan -> compound -> rendah
# dengan -> compound -> rendah
# nilai -> compound -> rendah
# yang -> compound -> rendah
# rendah -> conj -> mengatakan
# , -> punct -> rendah
# para -> nmod -> harus
# perangkat -> nmod -> harus
# daerah -> compound -> harus
# harus -> nmod -> RNB
# memenangkan -> nmod -> RNB
# “ -> punct -> RNB
# perusahaan -> compound -> ibu
# ibu -> nmod -> RNB
# ” -> punct -> RNB
# PT -> compound -> RNB
# RNB -> conj -> rendah
# . -> punct -> juga
# “ -> punct -> berpotensi
# Sehingga -> compound -> juga
# hal -> compound -> juga
# itu -> compound -> juga
# juga -> nsubj -> berpotensi
# berpotensi -> ROOT -> berpotensi
# dapat -> compound -> negara
# menimbulkan -> compound -> kerugian
# kerugian -> compound -> negara
# keuangan -> compound -> negara
# negara -> dobj -> berpotensi
# , -> punct -> negara
# ” -> punct -> ujarnya
# ujarnya -> appos -> negara
# . -> punct -> berpotensi
# Asep -> compound -> mengatakan
# mengatakan -> nmod -> kepada
# , -> punct -> mengatakan
# setiap -> compound -> yang
# perangkat -> compound -> yang
# daerah -> compound -> yang
# yang -> compound -> menyerahkan
# akan -> compound -> menyerahkan
# melakukan -> compound -> menyerahkan
# pengadaan -> compound -> menyerahkan
# diminta -> compound -> menyerahkan
# menyerahkan -> conj -> mengatakan
# Harga -> compound -> Sendiri
# Perkiraan -> compound -> Sendiri
# Sendiri -> conj -> mengatakan
# ( -> punct -> HPS
# HPS -> appos -> Sendiri
# ) -> punct -> HPS
# kepada -> compound -> awal
# PT -> compound -> awal
# RNB -> compound -> awal
# di -> compound -> awal
# awal -> ROOT -> awal
# , -> punct -> awal
# agar -> compound -> PT
# PT -> compound -> bisa
# RNB -> compound -> bisa
# bisa -> appos -> awal
# menyesuaikan -> compound -> nilai
# nilai -> compound -> mendekati
# penawaran -> compound -> mendekati
# yang -> compound -> mendekati
# mendekati -> compound -> HPS
# angka -> compound -> HPS
# HPS -> appos -> awal
# . -> punct -> awal
# “ -> punct -> jasa
# Hal -> nmod -> dalam
# itu -> nmod -> dalam
# melanggar -> appos -> itu
# prosedur -> amod -> dalam
# dalam -> compound -> proses
# proses -> compound -> jasa
# pengadaan -> compound -> jasa
# barang -> compound -> jasa
# dan -> compound -> jasa
# jasa -> ROOT -> jasa
# , -> punct -> jasa
# ” -> punct -> jasa
# tuturnya -> advmod -> jasa
# . -> punct -> jasa
# Asep -> compound -> mengungkapkan
# juga -> compound -> mengungkapkan
# mengungkapkan -> ROOT -> mengungkapkan
# , -> punct -> mengungkapkan
# sepanjang -> compound -> tahun
# tahun -> appos -> mengungkapkan
# 2025 -> nummod -> tahun
# , -> punct -> mengungkapkan
# PT -> compound -> mendominasi
# RNB -> compound -> mendominasi
# mendominasi -> nmod -> jasa
# proyek -> compound -> jasa
# pengadaan -> compound -> jasa
# barang -> compound -> jasa
# dan -> compound -> jasa
# jasa -> conj -> mengungkapkan
# ( -> punct -> jasa
# PBJ -> appos -> jasa
# ) -> punct -> jasa
# di -> compound -> Pekalongan
# Pemkab -> compound -> Pekalongan
# Pekalongan -> compound -> dengan
# dengan -> appos -> mengungkapkan
# mengerjakan -> compound -> jasa
# pengadaan -> compound -> jasa
# jasa -> nsubj -> outsourcing
# outsourcing -> acl -> dengan
# di -> prt -> outsourcing
# 17 -> nummod -> outsourcing
# Perangkat -> compound -> Daerah
# Daerah -> dobj -> outsourcing
# , -> punct -> Daerah
# 3 -> nummod -> RSUD
# RSUD -> appos -> Daerah
# , -> punct -> RSUD
# dan -> nmod -> Kecamatan
# 1 -> nummod -> dan
# Kecamatan -> appos -> RSUD
# . -> punct -> mengungkapkan
# Baca -> compound -> juga
# juga -> ROOT -> juga
# : -> punct -> juga
# Dominasi -> compound -> Outsourcing
# Proyek -> compound -> Outsourcing
# Outsourcing -> appos -> juga
# , -> punct -> Outsourcing
# Keluarga -> compound -> Bupati
# Bupati -> compound -> Fadia
# Pekalongan -> compound -> Fadia
# Fadia -> compound -> Arafiq
# Arafiq -> compound -> Untung
# Kantongi -> compound -> Untung
# Untung -> punct -> juga
# Rp -> ROOT -> Rp
# 19 -> nummod -> itu
# Miliar -> compound -> itu
# Selain -> compound -> itu
# itu -> pobj -> Rp
# , -> punct -> itu
# sepanjang -> compound -> tahun
# tahun -> appos -> itu
# 2023 -> nummod -> tahun
# - -> punct -> tahun
# 2026 -> nummod -> tahun
# , -> punct -> itu
# terdapat -> nmod -> bersumber
# transaksi -> nmod -> bersumber
# masuk -> compound -> ke
# ke -> compound -> senilai
# PT -> compound -> senilai
# RNB -> compound -> senilai
# senilai -> compound -> Rp46
# Rp46 -> compound -> miliar
# miliar -> compound -> bersumber
# yang -> compound -> bersumber
# bersumber -> compound -> antara
# dari -> compound -> kontrak
# kontrak -> compound -> antara
# antara -> compound -> Pekalongan
# PT -> compound -> Pekalongan
# RNB -> compound -> Pekalongan
# dan -> compound -> Pekalongan
# Perangkat -> compound -> Pekalongan
# Daerah -> compound -> Pekalongan
# di -> compound -> Pekalongan
# Pemkab -> compound -> Pekalongan
# Pekalongan -> appos -> itu
# . -> punct -> Rp
# Kemudian -> amod -> tersebut
# dari -> compound -> tersebut
# uang -> compound -> tersebut
# tersebut -> ROOT -> tersebut
# , -> punct -> tersebut
# yang -> nmod -> pegawai
# digunakan -> amod -> pegawai
# untuk -> compound -> pembayaran
# pembayaran -> compound -> gaji
# gaji -> compound -> pegawai
# pegawai -> compound -> outsourcing
# outsourcing -> appos -> tersebut
# hanya -> compound -> sebesar
# sebesar -> compound -> miliar
# Rp22 -> compound -> miliar
# miliar -> dobj -> outsourcing
# . -> punct -> tersebut
# Sisa -> compound -> diantaranya
# diantaranya -> nsubj -> dengan
# , -> punct -> diantaranya
# dinikmati -> compound -> kepada
# dan -> compound -> kepada
# dibagikan -> compound -> kepada
# kepada -> compound -> keluarga
# keluarga -> appos -> diantaranya
# Bupati -> appos -> keluarga
# dengan -> ROOT -> dengan
# total -> amod -> mencapai
# mencapai -> dobj -> dengan
# Rp19 -> compound -> miliar
# miliar -> npadvmod -> dengan
# ( -> punct -> miliar
# sekitar -> appos -> miliar
# 40 -> nummod -> persen
# persen -> appos -> sekitar
# ) -> punct -> sekitar
# dari -> nmod -> transaksi
# total -> amod -> transaksi
# transaksi -> appos -> miliar
# . -> punct -> dengan
# Rinciannya -> nsubj -> sebesar
# , -> punct -> Rinciannya
# Bupati -> compound -> Arafiq
# Pekalongan -> compound -> Fadia
# Fadia -> compound -> Arafiq
# Arafiq -> conj -> Rinciannya
# sebesar -> ROOT -> sebesar
# Rp -> prep -> sebesar
# 5,5 -> compound -> miliar
# miliar -> pobj -> Rp
# ; -> punct -> sebesar
# Muhammad -> compound -> Ashraff
# Sabiq -> compound -> Ashraff
# Ashraff -> punct -> sebesar
# ( -> punct -> Ashraff
# suami -> compound -> bupati
# bupati -> appos -> Ashraff
# ) -> punct -> Ashraff
# Rp -> compound -> 1,1
# 1,1 -> nummod -> miliar
# miliar -> ROOT -> miliar
# ; -> punct -> miliar
# Rul -> compound -> Bayatun
# Bayatun -> compound -> selaku
# selaku -> compound -> PT
# Direktur -> compound -> PT
# PT -> compound -> RNB
# RNB -> punct -> miliar
# Rp -> prep -> Ashraff
# 2,3 -> nummod -> miliar
# miliar -> pobj -> Rp
# ; -> punct -> Rp
# Muhammad -> compound -> Ashraff
# Sabiq -> compound -> Ashraff
# Ashraff -> ROOT -> Ashraff
# ( -> punct -> Ashraff
# anak -> compound -> bupati
# bupati -> appos -> Ashraff
# ) -> punct -> Ashraff
# Rp -> prep -> Mehnaz
# 4,6 -> nummod -> miliar
# miliar -> pobj -> Rp
# ; -> punct -> Mehnaz
# Mehnaz -> ROOT -> Mehnaz
# ( -> punct -> Mehnaz
# anak -> compound -> bupati
# bupati -> appos -> Mehnaz
# ) -> punct -> Mehnaz
# Rp -> ROOT -> Rp
# 2,5 -> pobj -> Rp
# miliar -> pobj -> Rp
# ; -> punct -> Rp
# serta -> nsubj -> dilakukan
# dilakukan -> compound -> penarikan
# penarikan -> nsubj -> Rp
# tunai -> pobj -> Rp
# sebesar -> nmod -> miliar
# Rp3 -> compound -> miliar
# miliar -> pobj -> Rp
# . -> punct -> Rp
# Asep -> compound -> mengatakan
# mengatakan -> ROOT -> mengatakan
# , -> punct -> mengatakan
# pengelolaan -> compound -> distribusi
# dan -> compound -> distribusi
# distribusi -> compound -> oleh
# uang -> compound -> diatur
# tersebut -> compound -> diatur
# diatur -> compound -> oleh
# oleh -> compound -> Arafiq
# Fadia -> compound -> Arafiq
# Arafiq -> appos -> mengatakan
# . -> punct -> mengatakan
# Ia -> ROOT -> Ia
# mengatakan -> amod -> Ia
# , -> punct -> pengaturan
# pengaturan -> conj -> Ia
# dilakukan -> nmod -> RSUD
# melalui -> compound -> komunikasi
# komunikasi -> nmod -> bernama
# WA -> compound -> Grup
# Grup -> compound -> bernama
# bernama -> nmod -> RSUD
# “ -> punct -> RSUD
# Belanja -> nmod -> RSUD
# RSUD -> dobj -> pengaturan
# ” -> punct -> RSUD
# bersama -> compound -> stafnya
# para -> compound -> stafnya
# stafnya -> conj -> pengaturan
# . -> punct -> pengaturan
# “ -> punct -> Bupati
# Setiap -> compound -> Bupati
# pengambilan -> compound -> Bupati
# uang -> compound -> Bupati
# untuk -> compound -> Bupati
# Bupati -> ROOT -> Bupati
# , -> punct -> Bupati
# staf -> compound -> melaporkan
# selalu -> nmod -> melaporkan
# melaporkan -> nmod -> tersebut
# , -> punct -> melaporkan
# mendokumentasikan -> conj -> melaporkan
# , -> punct -> mendokumentasikan
# dan -> compound -> mengirimkannya
# mengirimkannya -> compound -> tersebut
# melalui -> compound -> tersebut
# WA -> compound -> Grup
# Grup -> compound -> tersebut
# tersebut -> appos -> Bupati
# . -> punct -> Bupati
# Penyidik -> compound -> juga
# juga -> compound -> terus
# masih -> compound -> terus
# akan -> compound -> terus
# terus -> compound -> juga
# menelusuri -> compound -> juga
# apakah -> compound -> juga
# perusahaan -> compound -> juga
# ini -> compound -> juga
# juga -> nsubj -> dalam
# digunakan -> amod -> modus
# untuk -> compound -> melakukan
# melakukan -> compound -> modus
# modus -> compound -> dalam
# dalam -> ROOT -> dalam
# penerimaan -> compound -> lainnya
# lainnya -> dobj -> dalam
# , -> punct -> dia
# ” -> punct -> dia
# ucap -> compound -> dia
# dia -> npadvmod -> dalam
# . -> punct -> dalam
# Atas -> compound -> perbuatannya
# perbuatannya -> nsubj -> dalam
# , -> punct -> perbuatannya
# Fadia -> nmod -> melakukan
# disangkakan -> amod -> telah
# telah -> compound -> melakukan
# melakukan -> compound -> sebagaimana
# tindak -> compound -> sebagaimana
# pidana -> compound -> sebagaimana
# korupsi -> compound -> sebagaimana
# sebagaimana -> appos -> perbuatannya
# diatur -> compound -> dalam
# dalam -> ROOT -> dalam
# Pasal -> dobj -> dalam
# 12 -> nummod -> huruf
# huruf -> nmod -> Nomor
# i -> nmod -> Pasal
# dan -> nmod -> Pasal
# Pasal -> nmod -> Nomor
# 12 -> compound -> B
# B -> compound -> Nomor
# Undang -> compound -> Undang
# - -> punct -> Undang
# Undang -> compound -> Nomor
# RI -> compound -> Nomor
# Nomor -> dobj -> dalam
# 31 -> nummod -> Nomor
# Tahun -> nmod -> tentang
# 1999 -> nummod -> Tahun
# tentang -> appos -> Nomor
# Pemberantasan -> compound -> Tindak
# Tindak -> compound -> Korupsi
# Pidana -> compound -> Korupsi
# Korupsi -> compound -> sebagaimana
# sebagaimana -> nsubj -> diubah
# telah -> appos -> sebagaimana
# diubah -> compound -> tentang
# dengan -> compound -> Nomor
# Undang -> compound -> Undang
# - -> punct -> Undang
# Undang -> compound -> Nomor
# RI -> compound -> Nomor
# Nomor -> nmod -> tentang
# 20 -> nummod -> Nomor
# Tahun -> nmod -> tentang
# 2001 -> nummod -> tentang
# tentang -> ROOT -> tentang
# Perubahan -> compound -> Atas
# Atas -> compound -> Undang
# Undang -> compound -> Undang
# - -> punct -> Undang
# Undang -> compound -> Nomor
# RI -> compound -> Nomor
# Nomor -> appos -> tentang
# 31 -> nummod -> Nomor
# Tahun -> nmod -> tentang
# 1999 -> nummod -> Tahun
# tentang -> appos -> tentang
# Pemberantasan -> compound -> Tindak
# Tindak -> appos -> tentang
# Pidana -> compound -> Jo
# Korupsi -> compound -> Jo
# Jo -> appos -> Tindak
# . -> punct -> tentang
# Pasal -> nmod -> ayat
# 127 -> nummod -> ayat
# ayat -> ROOT -> ayat
# ( -> punct -> ayat
# 1 -> nummod -> Nomor
# ) -> punct -> Nomor
# Undang -> nmod -> Undang
# - -> punct -> Undang
# Undang -> nmod -> Nomor
# Nomor -> nmod -> tentang
# 1 -> nummod -> Nomor
# Tahun -> nmod -> tentang
# 2023 -> nummod -> Tahun
# tentang -> compound -> Pidana
# Kitab -> compound -> Pidana
# Undang -> compound -> Undang
# - -> punct -> Undang
# Undang -> compound -> Pidana
# Hukum -> compound -> Pidana
# Pidana -> appos -> ayat
# ( -> punct -> KUHP
# KUHP -> appos -> Pidana
# ) -> punct -> Pidana
# . -> punct -> Pidana
#                -> dep -> .
# Copyright -> ROOT -> Copyright
# 2008 -> nummod -> Copyright
# - -> punct -> 2026
# 2026 -> prep -> Copyright
# PT -> appos -> Copyright
# . -> punct -> Copyright
# Kompas -> compound -> Cyber
# Cyber -> compound -> Media
# Media -> ROOT -> Media
# ( -> punct -> Media
# Kompas -> compound -> Gramedia
# Gramedia -> compound -> Group
# Digital -> compound -> Group
# Group -> appos -> Media
# ) -> punct -> Media
# . -> punct -> Media
# All -> det -> Rights
# Rights -> nsubj -> Reserved
# Reserved -> ROOT -> Reserved
# . -> punct -> Reserved

# %% [markdown]
# # Knowledge Graph Entity

# %% [markdown]
# # Knowledge Graph
#
# ## Pengertian
#
# **Knowledge Graph** adalah representasi pengetahuan dalam bentuk **graf** yang menunjukkan hubungan antar entitas.
#
# Knowledge graph terdiri dari tiga komponen utama:
#
# - **Entity (Node)** → objek atau konsep
# - **Relation (Edge)** → hubungan antar entitas
# - **Triple** → struktur pengetahuan *(Subject – Predicate – Object)*
#
# ---
#
# ## Contoh Knowledge Graph
#
# Kalimat:
#
# Barack Obama was born in Hawaii
#
# Triple yang dihasilkan:
#
# (Barack Obama) — born_in — (Hawaii)
#
# Struktur graf:
#
# Barack Obama → born_in → Hawaii
#
# ## Proses Pembuatan Knowledge Graph dalam NLP
#
# 1. Text Collection
# 2. Named Entity Recognition (NER)
# 3. Dependency Parsing
# 4. Relation Extraction
# 5. Graph Construction
#
# ---
#
# ## Kegunaan Knowledge Graph
#
# Knowledge graph digunakan untuk:
#
# - **Search Engine** (Google Knowledge Graph)
# - **Question Answering System**
# - **Recommendation System**
# - **Semantic Search**
#
# ---

# %%
# Knowledge Graph Entity

G = nx.Graph()

entities = [ent.text for ent in doc.ents]

for ent in entities:
  G.add_node(ent)

for i in range(len(entities)-1):
  G.add_edge(entities[i], entities[i+1])

plt.figure(figsize=(12,12))

nx.draw_networkx(G, with_labels=True,node_size = 1000, font_size = 8)
plt.show()
